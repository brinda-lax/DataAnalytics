# %% [markdown]
# <a href="https://colab.research.google.com/github/brinda-lax/DataAnalytics/blob/main/paraOlympicsparisforIndian2024.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Importing Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import plotly.express as px
import matplotlib.pyplot as plt
Atheletes=pd.read_csv('/content/sample_data/athletes.csv')

# %% [markdown]
# #Indian seggregating data

# %%
#Indian=Atheletes[Atheletes['country']=='India']
#Indian.to_csv('Indian.csv')

# %% [markdown]
# #Indian Atheletes Data

# %%
Indian=pd.read_csv('/content/sample_data/Indian.csv')
Indian.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 84 entries, 0 to 83
# Data columns (total 36 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Unnamed: 0          84 non-null     int64
#  1   code                84 non-null     int64
#  2   name                84 non-null     object
#  3   name_short          84 non-null     object
#  4   name_tv             84 non-null     object
#  5   gender              84 non-null     object
#  6   function            84 non-null     object
#  7   country_code        84 non-null     object
#  8   country             84 non-null     object
#  9   country_long        84 non-null     object
#  10  nationality         84 non-null     object
#  11  nationality_long    84 non-null     object
#  12  nationality_code    84 non-null     object
#  13  height              84 non-null     int64
#  14  weight              84 non-null     float64
#  15  disciplines         84 non-null     object
#  16  events              84 non-null     object
#  17  birth_date          84 non-null     object
#  18  birth_place         32 non-null     object
#  19  birth_country       52 non-null     object
#  20  residence_place     49 non-null     object
#  21  residence_country   66 non-null     object
#  22  nickname            18 non-null     object
#  23  hobbies             26 non-null     object
#  24  occupation          73 non-null     object
#  25  education           47 non-null     object
#  26  family              13 non-null     object
#  27  lang                76 non-null     object
#  28  coach               64 non-null     object
#  29  reason              73 non-null     object
#  30  hero                38 non-null     object
#  31  influence           50 non-null     object
#  32  philosophy          42 non-null     object
#  33  sporting_relatives  7 non-null      object
#  34  ritual              7 non-null      object
#  35  other_sports        15 non-null     object
# dtypes: float64(1), int64(3), object(32)
# memory usage: 23.8+ KB

# %% [markdown]
# #Eliminating null and checking if any

# %%
Indian.fillna(0,inplace=True)
Indian.isna()
Indian.isnull().sum()
Indian.isnull().values.any()
# Out:
# False

# %%
Indian.reset_index(inplace=True)
#Indian.head()
Indian.drop('index',axis=1,inplace=True)
#print(Indian.columns)
Indian.drop('Unnamed: 0',axis=1,inplace=True)
Indian.head()
# Out:
#       code                  name   name_short               name_tv  gender  \
# 0  1989522           PAL Preethi        PAL P           Preethi PAL  Female
# 1  1989636      JEEVANJI Deepthi   JEEVANJI D      Deepthi JEEVANJI  Female
# 2  1989866                 SUMIT        SUMIT                 SUMIT    Male
# 3  1989938  SARGAR Sandip Sanjay    SARGAR SS  Sandip Sanjay SARGAR    Male
# 4  1989988           AJEET SINGH  AJEET SINGH           AJEET SINGH    Male
#
#   function country_code country country_long nationality  ... family  \
# 0  Athlete          IND   India        India       India  ...      0
# 1  Athlete          IND   India        India       India  ...      0
# 2  Athlete          IND   India        India       India  ...      0
# 3  Athlete          IND   India        India       India  ...      0
# 4  Athlete          IND   India        India       India  ...      0
#
#              lang           coach  \
# 0  English, Hindi  Gajendra Singh
# 1         English        N Ramesh
# 2  English, Hindi      Arun Kumar
# 3               0               0
# 4  English, Hindi               0
#
#                                               reason  \
# 0  "I was interested due to the enjoyment I felt ...
# 1  She was spotted competing in a state-level ath...
# 2  He competed in non-Para wrestling until 2015, ...
# 3                                                  0
# 4  "During recuperation and my inner turmoil I wa...
#
#                                                 hero  \
# 0  Coach Gajendra Singh, Indian Para athletics Si...
# 1                                                  0
# 2  Indian freestyle wrestler Yogeshwar Dutt. (oly...
# 3                                                  0
# 4                                                  0
#
#                                            influence  \
# 0  Her family and Indian Para athletics competito...
# 1                                                  0
# 2  Coach Virender Dhankhar. (Sports Authority of ...
# 3                                                  0
# 4                                                  0
#
#                                           philosophy sporting_relatives  \
# 0  "I believe change is the only constant thing, ...                  0
# 1  "If you believe in yourself and have dedicatio...                  0
# 2  "Success doesn't happen overnight. Keep your e...                  0
# 3                                                  0                  0
# 4  "To me, pain is like jewellery on an athlete. ...                  0
#
#   ritual                                       other_sports
# 0      0                                                  0
# 1      0                                                  0
# 2      0  He has competed in non-Para javelin at nationa...
# 3      0                                                  0
# 4      0                                                  0
#
# [5 rows x 35 columns]

# %%
print(Indian.columns)
# Out:
# Index(['code', 'name', 'name_short', 'name_tv', 'gender', 'function',
#        'country_code', 'country', 'country_long', 'nationality',
#        'nationality_long', 'nationality_code', 'height', 'weight',
#        'disciplines', 'events', 'birth_date', 'birth_place', 'birth_country',
#        'residence_place', 'residence_country', 'nickname', 'hobbies',
#        'occupation', 'education', 'family', 'lang', 'coach', 'reason', 'hero',
#        'influence', 'philosophy', 'sporting_relatives', 'ritual',
#        'other_sports'],
#       dtype='object')

# %%
Indian_atheletes=Indian[['name','gender','lang','residence_place','disciplines','coach','occupation','education']]
Indian_atheletes
# Out:
#                             name  gender            lang residence_place  \
# 0                    PAL Preethi  Female  English, Hindi   MUZAFFARNAGAR
# 1               JEEVANJI Deepthi  Female         English       HYDERABAD
# 2                          SUMIT    Male  English, Hindi         SONIPAT
# 3           SARGAR Sandip Sanjay    Male               0               0
# 4                    AJEET SINGH    Male  English, Hindi         GWALIOR
# ..                           ...     ...             ...             ...
# 79                       RAM PAL    Male  English, Hindi               0
# 80                     DHARAMBIR    Male           Hindi         SONIPAT
# 81              KUMAR Amit Kumar    Male  English, Hindi         SONIPAT
# 82  CHAUDHARY Bhavanaben Ajabaji  Female           Hindi               0
# 83                    OJHA Pooja  Female         English               0
#
#            disciplines                        coach               occupation  \
# 0   ['Para Athletics']               Gajendra Singh                  Athlete
# 1   ['Para Athletics']                     N Ramesh                  Athlete
# 2   ['Para Athletics']                   Arun Kumar                  Athlete
# 3   ['Para Athletics']                            0                        0
# 4   ['Para Athletics']                            0                  Athlete
# ..                 ...                          ...                      ...
# 79  ['Para Athletics']                            0  Athlete, Public Servant
# 80  ['Para Athletics']  Amit Saroha [personal], IND                        0
# 81  ['Para Athletics']                            0                  Athlete
# 82  ['Para Athletics']                 Sunil Tanwer                  Student
# 83      ['Para Canoe']     Mayank Thakur [national]   Athlete, Postal Worker
#
#                                             education
# 0   Forestry Studies - Chaudhary Charan Singh Univ...
# 1                                                   0
# 2           Commerce - Ramjas College, New Delhi, IND
# 3                                                   0
# 4   Lakshmibai National Institute of Physical Educ...
# ..                                                ...
# 79          Maharshi Dayanand University, Rohtak, IND
# 80        Maheshwari Dayanand University, Rohtak, IND
# 81          Maharshi Dayanand University, Rohtak, IND
# 82              Kalinga University, Chhattisgarh, IND
# 83                                                  0
#
# [84 rows x 8 columns]

# %% [markdown]
# #Gender based Participation From India

# %%
IndianGenderParticipation=Indian_atheletes.groupby('gender')['name'].count()
IndianGenderParticipation = IndianGenderParticipation.to_frame(name='Count of athletes')
IndianGenderParticipation.reset_index(inplace=True)
IndianGenderParticipation
sns.barplot(x='gender',y='Count of athletes',hue='gender',data=IndianGenderParticipation)
plt.show()

# %%
IndianAtheletesSport=Indian_atheletes.groupby('disciplines').size().sort_values(ascending=False)
#IndianAtheletesSport.reset_index(inplace=True)
IndianAtheletesSport = IndianAtheletesSport.to_frame(name='Count of athletes')
IndianAtheletesSport.reset_index(inplace=True)
#IndianAtheletesSport.rename(columns={0:'Count of athletes'},inplace=True)
IndianAtheletesSport
sns.barplot(y='disciplines',x='Count of athletes',hue='disciplines',data=IndianAtheletesSport)
plt.show()

# %% [markdown]
# #Reading Medals count

# %%
Medals=pd.read_csv('/content/sample_data/medallists.csv')
#Medals.head()
print(Medals.columns)
#Medals
Medals_Indian=Medals[Medals['country_code']=='IND'].copy()

Medals_Indian.sort_values(by='medal_code',ascending=True,inplace=True)
Medals_Indian.reset_index(drop='True',inplace=True)

MedalCount=Medals_Indian.groupby('medal_type').size()
MedalCount=MedalCount.to_frame(name='Count of Medals')
MedalCount.reset_index(inplace=True)
plt.figure(figsize=(10,5))
sns.barplot(x='medal_type',y='Count of Medals',hue='medal_type',data=MedalCount)
plt.show()
#Medals_Indian.drop('index',axis=1,inplace=True)
#Medals_Indian.to_csv('IndianMedals.csv')
# Out:
# Index(['medal_date', 'medal_type', 'medal_code', 'name', 'gender',
#        'country_code', 'country', 'country_long', 'nationality_code',
#        'nationality', 'nationality_long', 'team', 'team_gender', 'discipline',
#        'event', 'event_type', 'url_event', 'birth_date', 'code_athlete',
#        'code_team'],
#       dtype='object')

# %% [markdown]
# #In Terms of piechart

# %%
MedalCount.plot(kind='pie',
                y='Count of Medals',  # The values to be plotted
                labels=MedalCount['medal_type'],  # The labels (medal types)
                autopct='%1.1f%%',  # Show percentages
                figsize=(8, 6),
                legend=False)
plt.title('The percentage of Medals Indian')

# Show the plot
plt.show()

# %%
Medals_Indian.fillna(0,inplace=True)
#Medals_Indian.isna()
#Medals_Indian.isnull().sum()
Medals_Indian.isnull().values.any()
# Out:
# False

# %%
Medals_Indian.head()
# Out:
#    medal_date  medal_type  medal_code             name gender country_code  \
# 0  2024-09-02  Gold Medal           1     NITESH Kumar   Male          IND
# 1  2024-09-06  Gold Medal           1    PRAVEEN KUMAR   Male          IND
# 2  2024-09-04  Gold Medal           1        DHARAMBIR   Male          IND
# 3  2024-09-02  Gold Medal           1            SUMIT   Male          IND
# 4  2024-09-04  Gold Medal           1  SINGH Harvinder   Male          IND
#
#   country country_long nationality_code nationality nationality_long team  \
# 0   India        India              IND       India            India    0
# 1   India        India              IND       India            India    0
# 2   India        India              IND       India            India    0
# 3   India        India              IND       India            India    0
# 4   India        India              IND       India            India    0
#
#   team_gender      discipline                          event event_type  \
# 0           0  Para Badminton              Men's Singles SL3       HATH
# 1           0  Para Athletics          Men's High Jump - T64        ATH
# 2           0  Para Athletics         Men's Club Throw - F51        ATH
# 3           0  Para Athletics      Men's Javelin Throw - F64        ATH
# 4           0    Para Archery  Men's Individual Recurve Open       HATH
#
#                                            url_event  birth_date  \
# 0  /en/paris-2024-paralympics/results/para-badmin...  1994-12-30
# 1  /en/paris-2024-paralympics/results/para-athlet...  2003-05-15
# 2  /en/paris-2024-paralympics/results/para-athlet...  1989-01-18
# 3  /en/paris-2024-paralympics/results/para-athlet...  1998-06-07
# 4  /en/paris-2024-paralympics/results/para-archer...  1991-02-25
#
#    code_athlete code_team
# 0     2499521.0         0
# 1     1990249.0         0
# 2     3415803.0         0
# 3     1989866.0         0
# 4     2488318.0         0

# %% [markdown]
# #Count of Athletes who won medals genderwise

# %%
atheletes_genderwise=Medals_Indian.groupby('gender')['medal_code'].count().reset_index(name='Count_of_Athletes')
atheletes_genderwise
# Out:
#    gender  Count_of_Athletes
# 0  Female                 11
# 1    Male                 19

# %% [markdown]
# #catplot for number of atheletes won genderwise

# %%
plt.figure(figsize=(5,5))
sns.set(style = 'whitegrid')
sns.catplot(x='gender',y='Count_of_Athletes',palette='bright',data=atheletes_genderwise)
plt.show()
# Out:
# <ipython-input-27-3e4232b6a91a>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.catplot(x='gender',y='Count_of_Athletes',palette='bright',data=atheletes_genderwise)

# %% [markdown]
# #Forecast of atheletes winning medals

# %%
growth_rate=atheletes_genderwise['Count_of_Athletes'].pct_change().iloc[-1]
growth_rate
forecast_female = atheletes_genderwise.loc[atheletes_genderwise['gender'] == 'Female', 'Count_of_Athletes'].values[0] * (1 + growth_rate)
forecast_male = atheletes_genderwise.loc[atheletes_genderwise['gender'] == 'Male', 'Count_of_Athletes'].values[0] * (1 + growth_rate)
#print("Forecast for Female:", round(forecast_female))
#print("Forecast for Male:", round(forecast_male))
forecast_df = pd.DataFrame({
    'gender': ['Female', 'Male'],
    'Forecast_Count_of_Athletes': [round(forecast_female), round(forecast_male)]
})
forecast_df
# Out:
#    gender  Forecast_Count_of_Athletes
# 0  Female                          19
# 1    Male                          33

# %% [markdown]
# #Sample Forecast

# %%
plt.figsize=(5,5)
sns.barplot(x='gender',y='Forecast_Count_of_Athletes',hue='gender',data=forecast_df)
plt.title('Number of Atheletes winning Medals from India in 2028')
plt.show()
